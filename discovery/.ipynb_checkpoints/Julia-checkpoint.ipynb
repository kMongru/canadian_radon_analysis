# %%
import numpy as np
import pandas as pd

results = pd.read_csv('radon-thoron.csv', encoding='latin-1')
results.head() # checking that rows can be printed
# Out:
#    resultNumber censusMetropolitanArea province forwardSortationAreaCodes  \
# 0             1            Calgary CMA       AB                         *
# 1             2            Calgary CMA       AB                         *
# 2             3            Calgary CMA       AB                         *
# 3             4            Calgary CMA       AB                         *
# 4             5            Calgary CMA       AB                         *
#
#    testDurationInDays averageRadonConcentrationInBqPerM3  \
# 0                  90                                 89
# 1                  92                                 18
# 2                  91                                114
# 3                  91                                185
# 4                  91                                 71
#
#   averageThoronConcentrationInBqPerM3
# 0                                 <15
# 1                                 <15
# 2                                 <15
# ...
