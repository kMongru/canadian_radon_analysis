# %%
import pandas as pd
import tensorflow as tf                            # LSTM
import numpy as np                                 # Vectorial computation
import itertools                                   # Combinatory
import datetime
import pgeocode
import seaborn as sns

# %% [markdown]
# ## Data reading

# %%
df = pd.read_csv('data/radon-data.csv')   # CSV reading
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv('data/radon-data.csv')   # CSV reading
#       2 df.head()
#       3 df.size
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ### Data cleaning

# %%
# Now we will parse the data, so it is usable
df.time = pd.to_datetime(df['time'], unit='s', origin='unix')      # date parse
df = df.drop(columns = ["time", "id", "sensor_id", "state_time"])  # drop useless columns
df.state = (df.state == "On").astype(int)                          # binarize state
df.head()
# Out:
#    radon  temperature  humidity  pressure  tvoc  state
# 0    202           25        50      1015     0      0
# 1    258           25        51      1015     0      1
# 2    202           24        51      1015     0      0
# 3    182           24        51      1015     0      0
# 4    189           24        51      1015     0      0

# %%
# we now select the data from the summer (longest clean data)
df_summer = df.iloc[36000:48000]
df_summer.shape
# Out:
# (12000, 6)

# %% [markdown]
# ### Data normalization

# %%
summer_min = df_summer.min() # needed to de-normalize data
summer_max = df_summer.max()

df_summer_normalized = (df_summer - summer_min) / (summer_max - summer_min)
df_summer_normalized.shape
# Out:
# (12000, 6)

# %% [markdown]
# ## Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from itertools import chain, combinations
reg = LinearRegression()

# %%
independent_vars = ["temperature", "humidity", "pressure", "tvoc", "state"]

# Function to get all combinations of the independent variables
def all_combinations(variables):
    return list(chain(*map(lambda x: combinations(variables, x), range(1, len(variables) + 1))))

# Get all combinations of independent variables
combinations = all_combinations(independent_vars)

# Dependent variable
dependent_var = "radon"

# Split the data into training (80%) and testing (20%) sets
X_train, X_test, y_train, y_test = train_test_split(df[independent_vars], df[dependent_var], test_size=0.2, random_state=42)

# Initialize a dictionary to store R-squared scores
r2_scores = {}

# Iterate over each combination of independent variables
for combo in combinations:
    # Train a linear regression model
    model = LinearRegression()
    model.fit(X_train[list(combo)], y_train)

    # Make predictions using the test set
    y_pred = model.predict(X_test[list(combo)])

    # Calculate R-squared score
    r2 = r2_score(y_test, y_pred)

    # Store the R-squared score in the dictionary
    r2_scores[combo] = r2

# Find the combination with the highest R-squared score
best_combo = max(r2_scores, key=r2_scores.get)

print("Best combination of independent variables:", best_combo)
print("Highest R-squared score:", r2_scores[best_combo])
# Out:
# Best combination of independent variables: ('temperature', 'humidity', 'pressure', 'state')
# Highest R-squared score: 0.021471490002529126

# %%
covariate_list = ["state", "humidity", "pressure", "tvoc", "temperature"]

results_df = pd.DataFrame(columns=["Covariates", "R-squared", "Predictions", "Accuracy"])

# loop over different number of covariates
for number_of_covariates in range(1, 6):
    # loop over different combinations of covariates
    for covariate_combination in itertools.combinations(covariate_list, number_of_covariates):
        # select the covariate combination and the target variable
        labels = df_summer_normalized['radon']
        train1 = df_summer_normalized[list(covariate_combination)]

        # split the data into training and testing sets
        from sklearn.model_selection import train_test_split
        x_train, x_test, y_train, y_test = train_test_split(train1, labels, test_size = 0.20, random_state = 2)

        # fit the linear regression model to the training data
        from sklearn.linear_model import LinearRegression
        reg = LinearRegression()
        reg.fit(x_train, y_train)

        # evaluate the performance of the model on the testing data
        
        predictions = reg.predict(x_test)
        accuracy = reg.score(x_test, y_test)

        # store the covariate combination, the R-squared score, and the predicted values in the dataframe
        results_df = results_df.append({"Covariates": covariate_combination, "R-squared": accuracy, 
                                        "Predictions": predictions, "Accuracy": accuracy}, ignore_index=True)

# sort the results dataframe by R-squared score in descending order
results_df.sort_values("R-squared", ascending=False, inplace=True)

# select the row with the highest R-squared score
best_model = results_df.iloc[0]

# print the best model information
print("Best model covariates:", best_model["Covariates"])
print("Best model R-squared score:", best_model["R-squared"])
print("Best model predictions:", best_model["Predictions"])
print("Best model accuracy:", best_model["Accuracy"])
# Out:
# C:\Users\Culle\AppData\Local\Temp\ipykernel_26368\3034273196.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({"Covariates": covariate_combination, "R-squared": accuracy,
# C:\Users\Culle\AppData\Local\Temp\ipykernel_26368\3034273196.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({"Covariates": covariate_combination, "R-squared": accuracy,
# C:\Users\Culle\AppData\Local\Temp\ipykernel_26368\3034273196.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({"Covariates": covariate_combination, "R-squared": accuracy,
# C:\Users\Culle\AppData\Local\Temp\ipykernel_26368\3034273196.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({"Covariates": covariate_combination, "R-squared": accuracy,
# C:\Users\Culle\AppData\Local\Temp\ipykernel_26368\3034273196.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({"Covariates": covariate_combination, "R-squared": accuracy,
# C:\Users\Culle\AppData\Local\Temp\ipykernel_26368\3034273196.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({"Covariates": covariate_combination, "R-squared": accuracy,
# C:\Users\Culle\AppData\Local\Temp\ipykernel_26368\3034273196.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({"Covariates": covariate_combination, "R-squared": accuracy,
# C:\Users\Culle\AppData\Local\Temp\ipykernel_26368\3034273196.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({"Covariates": covariate_combination, "R-squared": accuracy,
# C:\Users\Culle\AppData\Local\Temp\ipykernel_26368\3034273196.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({"Covariates": covariate_combination, "R-squared": accuracy,
# C:\Users\Culle\AppData\Local\Temp\ipykernel_26368\3034273196.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({"Covariates": covariate_combination, "R-squared": accuracy,
# C:\Users\Culle\AppData\Local\Temp\ipykernel_26368\3034273196.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({"Covariates": covariate_combination, "R-squared": accuracy,
# C:\Users\Culle\AppData\Local\Temp\ipykernel_26368\3034273196.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({"Covariates": covariate_combination, "R-squared": accuracy,
# C:\Users\Culle\AppData\Local\Temp\ipykernel_26368\3034273196.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({"Covariates": covariate_combination, "R-squared": accuracy,
# C:\Users\Culle\AppData\Local\Temp\ipykernel_26368\3034273196.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({"Covariates": covariate_combination, "R-squared": accuracy,
# C:\Users\Culle\AppData\Local\Temp\ipykernel_26368\3034273196.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({"Covariates": covariate_combination, "R-squared": accuracy,
# C:\Users\Culle\AppData\Local\Temp\ipykernel_26368\3034273196.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({"Covariates": covariate_combination, "R-squared": accuracy,
# C:\Users\Culle\AppData\Local\Temp\ipykernel_26368\3034273196.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({"Covariates": covariate_combination, "R-squared": accuracy,
# C:\Users\Culle\AppData\Local\Temp\ipykernel_26368\3034273196.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({"Covariates": covariate_combination, "R-squared": accuracy,
# C:\Users\Culle\AppData\Local\Temp\ipykernel_26368\3034273196.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({"Covariates": covariate_combination, "R-squared": accuracy,
# C:\Users\Culle\AppData\Local\Temp\ipykernel_26368\3034273196.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({"Covariates": covariate_combination, "R-squared": accuracy,
# C:\Users\Culle\AppData\Local\Temp\ipykernel_26368\3034273196.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({"Covariates": covariate_combination, "R-squared": accuracy,
# C:\Users\Culle\AppData\Local\Temp\ipykernel_26368\3034273196.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({"Covariates": covariate_combination, "R-squared": accuracy,
# C:\Users\Culle\AppData\Local\Temp\ipykernel_26368\3034273196.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({"Covariates": covariate_combination, "R-squared": accuracy,
# C:\Users\Culle\AppData\Local\Temp\ipykernel_26368\3034273196.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({"Covariates": covariate_combination, "R-squared": accuracy,
# Best model covariates: ('state', 'pressure', 'tvoc')
# Best model R-squared score: 0.11719194665200394
# Best model predictions: [0.06671249 0.06389529 0.06722831 ... 0.05444427 0.09683787 0.06137196]
# Best model accuracy: 0.11719194665200394
# C:\Users\Culle\AppData\Local\Temp\ipykernel_26368\3034273196.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({"Covariates": covariate_combination, "R-squared": accuracy,
# C:\Users\Culle\AppData\Local\Temp\ipykernel_26368\3034273196.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({"Covariates": covariate_combination, "R-squared": accuracy,
# C:\Users\Culle\AppData\Local\Temp\ipykernel_26368\3034273196.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({"Covariates": covariate_combination, "R-squared": accuracy,
# C:\Users\Culle\AppData\Local\Temp\ipykernel_26368\3034273196.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({"Covariates": covariate_combination, "R-squared": accuracy,
# C:\Users\Culle\AppData\Local\Temp\ipykernel_26368\3034273196.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({"Covariates": covariate_combination, "R-squared": accuracy,
# C:\Users\Culle\AppData\Local\Temp\ipykernel_26368\3034273196.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({"Covariates": covariate_combination, "R-squared": accuracy,
# C:\Users\Culle\AppData\Local\Temp\ipykernel_26368\3034273196.py:33: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   results_df = results_df.append({"Covariates": covariate_combination, "R-squared": accuracy,

# %%
results_df
# Out:
#                                         Covariates  R-squared  \
# 0                                         (state,)   0.089740
# 1                                      (humidity,)   0.002068
# 2                                      (pressure,)   0.019363
# 3                                          (tvoc,)   0.007322
# 4                                   (temperature,)   0.000032
# 5                                (state, humidity)   0.090604
# 6                                (state, pressure)   0.108232
# 7                                    (state, tvoc)   0.089999
# 8                             (state, temperature)   0.089755
# 9                             (humidity, pressure)   0.019438
# 10                                (humidity, tvoc)   0.009780
# 11                         (humidity, temperature)   0.002010
# 12                                (pressure, tvoc)   0.032094
# 13                         (pressure, temperature)   0.019380
# 14                             (tvoc, temperature)   0.007584
# 15                     (state, humidity, pressure)   0.108217
# 16                         (state, humidity, tvoc)   0.090922
# 17                  (state, humidity, temperature)   0.090592
# 18                         (state, pressure, tvoc)   0.110080
# 19                  (state, pressure, temperature)   0.108300
# 20                      (state, tvoc, temperature)   0.090034
# 21                      (humidity, pressure, tvoc)   0.032221
# 22               (humidity, pressure, temperature)   0.019464
# 23                   (humidity, tvoc, temperature)   0.009851
# 24                   (pressure, tvoc, temperature)   0.032102
# 25               (state, humidity, pressure, tvoc)   0.110071
# 26        (state, humidity, pressure, temperature)   0.108292
# 27            (state, humidity, tvoc, temperature)   0.090918
# 28            (state, pressure, tvoc, temperature)   0.110100
# 29         (humidity, pressure, tvoc, temperature)   0.032204
# 30  (state, humidity, pressure, tvoc, temperature)   0.110094
#
#                                           Predictions  Accuracy
# 0   [0.06444449250417335, 0.06444449250417335, 0.0...  0.089740
# 1   [0.08394026178824344, 0.0835251293702265, 0.08...  0.002068
# 2   [0.0839194038465462, 0.0839194038465462, 0.083...  0.019363
# 3   [0.08489820186990166, 0.07967698163434679, 0.0...  0.007322
# 4   [0.08330054144114876, 0.08274105687784222, 0.0...  0.000032
# 5   [0.06474635717971501, 0.0644308847802571, 0.06...  0.090604
# 6   [0.06532544871844312, 0.06532544871844312, 0.0...  0.108232
# 7   [0.06488961050407038, 0.06387642608691062, 0.0...  0.089999
# 8   [0.06430498805449492, 0.06401761198710848, 0.0...  0.089755
# 9   [0.08393697521951732, 0.08391545590716801, 0.0...  0.019438
# 10  [0.08531683918592037, 0.07953063775844602, 0.0...  0.009780
# 11  [0.08371271824876701, 0.08289159803202686, 0.0...  0.002010
# 12  [0.08579316974669125, 0.07850400200328228, 0.0...  0.032094
# 13  [0.08395473420117769, 0.08402287207663553, 0.0...  0.019380
# 14  [0.0844907954854193, 0.07831904171207255, 0.08...  0.007584
# 15  [0.06531316411953703, 0.06532752462989846, 0.0...  0.108217
# 16  [0.06523848565681836, 0.06381573358025373, 0.0...  0.090922
# 17  [0.0646531914125288, 0.06416352858324714, 0.06...  0.090592
# 18  [0.06664912762218184, 0.06377399267642804, 0.0...  0.110080
# 19  [0.06544288222171535, 0.06567739800774666, 0.0...  0.108300
# 20  [0.06474202922049353, 0.0633342037635979, 0.06...  0.090034
# 21  [0.0858219396940815, 0.0784964876930071, 0.087...  0.032221
# 22  [0.08397760244119368, 0.0840289316087718, 0.08...  0.019464
# 23  [0.08496107928686047, 0.07841939913303929, 0.0...  0.009851
# 24  [0.08567395403070695, 0.07811809833974293, 0.0...  0.032102
# 25  [0.06664206305682348, 0.06377539544972446, 0.0...  0.110071
# 26  [0.06543513491606834, 0.0656751561586864, 0.06...  0.108292
# 27  [0.06512809160285216, 0.06344160856389527, 0.0...  0.090918
# 28  [0.0666975938929427, 0.06394231314767407, 0.06...  0.110100
# 29  [0.08570123641979807, 0.0781249660794228, 0.08...  0.032204
# 30  [0.06669252856290005, 0.06394093679294258, 0.0...  0.110094

# %%
results_sorted = results.sort_values(by='RMSE')
print(results_sorted)
# Out:
#                                         Covariates  R-squared      RMSE  \
# 28            (state, pressure, tvoc, temperature)   0.110100  0.058131
# 31  (state, humidity, pressure, tvoc, temperature)   0.110094  0.058131
# 30  (state, humidity, pressure, tvoc, temperature)   0.110094  0.058131
# 18                         (state, pressure, tvoc)   0.110080  0.058131
# 25               (state, humidity, pressure, tvoc)   0.110071  0.058132
# 19                  (state, pressure, temperature)   0.108300  0.058189
# 26        (state, humidity, pressure, temperature)   0.108292  0.058190
# 6                                (state, pressure)   0.108232  0.058192
# 15                     (state, humidity, pressure)   0.108217  0.058192
# 16                         (state, humidity, tvoc)   0.090922  0.058754
# 27            (state, humidity, tvoc, temperature)   0.090918  0.058754
# 5                                (state, humidity)   0.090604  0.058764
# 17                  (state, humidity, temperature)   0.090592  0.058764
# 20                      (state, tvoc, temperature)   0.090034  0.058782
# 7                                    (state, tvoc)   0.089999  0.058783
# 8                             (state, temperature)   0.089755  0.058791
# 0                                         (state,)   0.089740  0.058792
# 21                      (humidity, pressure, tvoc)   0.032221  0.060621
# 29         (humidity, pressure, tvoc, temperature)   0.032204  0.060621
# 24                   (pressure, tvoc, temperature)   0.032102  0.060625
# 12                                (pressure, tvoc)   0.032094  0.060625
# 22               (humidity, pressure, temperature)   0.019464  0.061019
# 9                             (humidity, pressure)   0.019438  0.061020
# 13                         (pressure, temperature)   0.019380  0.061022
# 2                                      (pressure,)   0.019363  0.061022
# 23                   (humidity, tvoc, temperature)   0.009851  0.061318
# 10                                (humidity, tvoc)   0.009780  0.061320
# 14                             (tvoc, temperature)   0.007584  0.061388
# 3                                          (tvoc,)   0.007322  0.061396
# 1                                      (humidity,)   0.002068  0.061558
# 11                         (humidity, temperature)   0.002010  0.061560
# 4                                   (temperature,)   0.000032  0.061621
#
#                                           Predictions  Accuracy
# 28  [0.0666975938929427, 0.06394231314767407, 0.06...  0.110100
# 31  [0.06669252856290005, 0.06394093679294258, 0.0...  0.110094
# 30  [0.06669252856290005, 0.06394093679294258, 0.0...  0.110094
# 18  [0.06664912762218184, 0.06377399267642804, 0.0...  0.110080
# 25  [0.06664206305682348, 0.06377539544972446, 0.0...  0.110071
# 19  [0.06544288222171535, 0.06567739800774666, 0.0...  0.108300
# 26  [0.06543513491606834, 0.0656751561586864, 0.06...  0.108292
# 6   [0.06532544871844312, 0.06532544871844312, 0.0...  0.108232
# 15  [0.06531316411953703, 0.06532752462989846, 0.0...  0.108217
# 16  [0.06523848565681836, 0.06381573358025373, 0.0...  0.090922
# 27  [0.06512809160285216, 0.06344160856389527, 0.0...  0.090918
# 5   [0.06474635717971501, 0.0644308847802571, 0.06...  0.090604
# 17  [0.0646531914125288, 0.06416352858324714, 0.06...  0.090592
# 20  [0.06474202922049353, 0.0633342037635979, 0.06...  0.090034
# 7   [0.06488961050407038, 0.06387642608691062, 0.0...  0.089999
# 8   [0.06430498805449492, 0.06401761198710848, 0.0...  0.089755
# 0   [0.06444449250417335, 0.06444449250417335, 0.0...  0.089740
# 21  [0.0858219396940815, 0.0784964876930071, 0.087...  0.032221
# 29  [0.08570123641979807, 0.0781249660794228, 0.08...  0.032204
# 24  [0.08567395403070695, 0.07811809833974293, 0.0...  0.032102
# 12  [0.08579316974669125, 0.07850400200328228, 0.0...  0.032094
# 22  [0.08397760244119368, 0.0840289316087718, 0.08...  0.019464
# 9   [0.08393697521951732, 0.08391545590716801, 0.0...  0.019438
# 13  [0.08395473420117769, 0.08402287207663553, 0.0...  0.019380
# 2   [0.0839194038465462, 0.0839194038465462, 0.083...  0.019363
# 23  [0.08496107928686047, 0.07841939913303929, 0.0...  0.009851
# 10  [0.08531683918592037, 0.07953063775844602, 0.0...  0.009780
# 14  [0.0844907954854193, 0.07831904171207255, 0.08...  0.007584
# 3   [0.08489820186990166, 0.07967698163434679, 0.0...  0.007322
# 1   [0.08394026178824344, 0.0835251293702265, 0.08...  0.002068
# 11  [0.08371271824876701, 0.08289159803202686, 0.0...  0.002010
# 4   [0.08330054144114876, 0.08274105687784222, 0.0...  0.000032

# %%
# We will use early stopping to select the best model
callback = tf.keras.callbacks.EarlyStopping(
    monitor              = 'val_loss',
    patience             = 30,
    restore_best_weights = True
)

# percentage of train samples
train_pct = 0.9

# We will store all the results in a data frame
results = pd.DataFrame(
    {i: [None]*15 for i in [1, 5, 10, 15, 25]}
)

cnt = 0 # helps counting

for number_of_covariates in range(4):
    for covariate_combination in itertools.combinations(("state", "humidity", "pressure", "tvoc"), 
                                                        number_of_covariates):
        print(f"EXECUTING OVER: {covariate_combination}".center(100, "*"))
        # We compute for each window size
        for window_size in [1, 5, 10, 15, 25]:
            print("\n")
            print(f"EXECUTING {window_size} WINDOW SIZE".center(100), "-")
            print("\n")
            windows = {i: generate_windows(df_summer_normalized[i], window_size, 1)
                        for i in ["radon"] + list(covariate_combination) }
            
            print("Windows computed, now building the model")
            
            data = mix_data(windows)
            N_total          = data.shape[0]
            test             = data[int(train_pct * N_total):, :, :]
            data             = data[:int(train_pct * N_total), :, :]
            
            model = tf.keras.models.Sequential(
                [
                    tf.keras.layers.InputLayer((window_size, len(windows.keys()))),
                    tf.keras.layers.LSTM(window_size * 2),
                    tf.keras.layers.Dense(16, activation = "relu"),
                    tf.keras.layers.Dense(16, activation = "relu"),
                    tf.keras.layers.Dense(1)
                ],
            )
            
            model.compile(
                loss = tf.keras.losses.MeanSquaredError(),
                metrics = tf.keras.metrics.RootMeanSquaredError(),
                optimizer = tf.keras.optimizers.RMSprop()
            )
            
            model.summary()
            
            model.fit(
                x                = data[:, :window_size, :],
                y                = data[:, window_size:, 0],
                epochs           = 1_000,
                shuffle          = False,
                validation_split = 0.2, 
                callbacks        = [callback,],
                verbose          = 0,
            )
            
            # Model trained
            
            # Now compute the test predictions and add them to the data frame
            rescale    = lambda x: x * (summer_max.radon - summer_min.radon) + summer_min.radon
            prediction = rescale( model.predict(test[:, :window_size, :]) )
            real       = rescale( test[:, window_size:, 0] )
            
            rmse_test = ( sum((prediction - real) ** 2) / len(prediction) ) ** (1/2)
            results[window_size][cnt] = rmse_test 
            print(f"Window {window_size}, covariates {covariate_combination}: {results[window_size][cnt]}")
        cnt += 1    
        print("*" * 100, "\n"*2)
# Out:
# *****************************************EXECUTING OVER: ()*****************************************
#
#
#                                       EXECUTING 1 WINDOW SIZE                                        -
#
#
# Windows computed, now building the model
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 2)                 32
#
#  dense (Dense)               (None, 16)                48
#
#  dense_1 (Dense)             (None, 16)                272
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 369
# Trainable params: 369
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 2ms/step
# Window 1, covariates (): [23.34748141]
#
#
#                                       EXECUTING 5 WINDOW SIZE                                        -
#
#
# Windows computed, now building the model
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 10)                480
#
#  dense_3 (Dense)             (None, 16)                176
#
#  dense_4 (Dense)             (None, 16)                272
#
#  dense_5 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 945
# Trainable params: 945
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 2ms/step
# Window 5, covariates (): [21.09082444]
#
#
#                                       EXECUTING 10 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 20)                1760
#
#  dense_6 (Dense)             (None, 16)                336
#
#  dense_7 (Dense)             (None, 16)                272
#
#  dense_8 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 2,385
# Trainable params: 2,385
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 3ms/step
# Window 10, covariates (): [21.24046198]
#
#
#                                       EXECUTING 15 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 30)                3840
#
#  dense_9 (Dense)             (None, 16)                496
#
#  dense_10 (Dense)            (None, 16)                272
#
#  dense_11 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 4,625
# Trainable params: 4,625
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 4ms/step
# Window 15, covariates (): [15.88256757]
#
#
#                                       EXECUTING 25 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_4 (LSTM)               (None, 50)                10400
#
#  dense_12 (Dense)            (None, 16)                816
#
#  dense_13 (Dense)            (None, 16)                272
#
#  dense_14 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 11,505
# Trainable params: 11,505
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 8ms/step
# Window 25, covariates (): [18.40624915]
# ****************************************************************************************************
#
#
# *************************************EXECUTING OVER: ('state',)*************************************
#
#
#                                       EXECUTING 1 WINDOW SIZE                                        -
#
#
# Windows computed, now building the model
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_5 (LSTM)               (None, 2)                 40
#
#  dense_15 (Dense)            (None, 16)                48
#
#  dense_16 (Dense)            (None, 16)                272
#
#  dense_17 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 377
# Trainable params: 377
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 2ms/step
# Window 1, covariates ('state',): [23.52270774]
#
#
#                                       EXECUTING 5 WINDOW SIZE                                        -
#
#
# Windows computed, now building the model
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 10)                520
#
#  dense_18 (Dense)            (None, 16)                176
#
#  dense_19 (Dense)            (None, 16)                272
#
#  dense_20 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 985
# Trainable params: 985
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 2ms/step
# Window 5, covariates ('state',): [18.46813002]
#
#
#                                       EXECUTING 10 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_7 (LSTM)               (None, 20)                1840
#
#  dense_21 (Dense)            (None, 16)                336
#
#  dense_22 (Dense)            (None, 16)                272
#
#  dense_23 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 2,465
# Trainable params: 2,465
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 4ms/step
# Window 10, covariates ('state',): [15.82426292]
#
#
#                                       EXECUTING 15 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_8 (LSTM)               (None, 30)                3960
#
#  dense_24 (Dense)            (None, 16)                496
#
#  dense_25 (Dense)            (None, 16)                272
#
#  dense_26 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 4,745
# Trainable params: 4,745
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 4ms/step
# Window 15, covariates ('state',): [15.28246876]
#
#
#                                       EXECUTING 25 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_9 (LSTM)               (None, 50)                10600
#
#  dense_27 (Dense)            (None, 16)                816
#
#  dense_28 (Dense)            (None, 16)                272
#
#  dense_29 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 11,705
# Trainable params: 11,705
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 5ms/step
# Window 25, covariates ('state',): [18.32253046]
# ****************************************************************************************************
#
#
# ***********************************EXECUTING OVER: ('humidity',)************************************
#
#
#                                       EXECUTING 1 WINDOW SIZE                                        -
#
#
# Windows computed, now building the model
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_10 (LSTM)              (None, 2)                 40
#
#  dense_30 (Dense)            (None, 16)                48
#
#  dense_31 (Dense)            (None, 16)                272
#
#  dense_32 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 377
# Trainable params: 377
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 2ms/step
# Window 1, covariates ('humidity',): [23.13558052]
#
#
#                                       EXECUTING 5 WINDOW SIZE                                        -
#
#
# Windows computed, now building the model
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_11 (LSTM)              (None, 10)                520
#
#  dense_33 (Dense)            (None, 16)                176
#
#  dense_34 (Dense)            (None, 16)                272
#
#  dense_35 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 985
# Trainable params: 985
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 5ms/step
# Window 5, covariates ('humidity',): [20.89733636]
#
#
#                                       EXECUTING 10 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_12 (LSTM)              (None, 20)                1840
#
#  dense_36 (Dense)            (None, 16)                336
#
#  dense_37 (Dense)            (None, 16)                272
#
#  dense_38 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 2,465
# Trainable params: 2,465
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 3ms/step
# Window 10, covariates ('humidity',): [19.71301372]
#
#
#                                       EXECUTING 15 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_13 (LSTM)              (None, 30)                3960
#
#  dense_39 (Dense)            (None, 16)                496
#
#  dense_40 (Dense)            (None, 16)                272
#
#  dense_41 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 4,745
# Trainable params: 4,745
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 5ms/step
# Window 15, covariates ('humidity',): [19.35152254]
#
#
#                                       EXECUTING 25 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_14 (LSTM)              (None, 50)                10600
#
#  dense_42 (Dense)            (None, 16)                816
#
#  dense_43 (Dense)            (None, 16)                272
#
#  dense_44 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 11,705
# Trainable params: 11,705
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 7ms/step
# Window 25, covariates ('humidity',): [17.96748799]
# ****************************************************************************************************
#
#
# ***********************************EXECUTING OVER: ('pressure',)************************************
#
#
#                                       EXECUTING 1 WINDOW SIZE                                        -
#
#
# Windows computed, now building the model
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_15 (LSTM)              (None, 2)                 40
#
#  dense_45 (Dense)            (None, 16)                48
#
#  dense_46 (Dense)            (None, 16)                272
#
#  dense_47 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 377
# Trainable params: 377
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 2ms/step
# Window 1, covariates ('pressure',): [32.44732531]
#
#
#                                       EXECUTING 5 WINDOW SIZE                                        -
#
#
# Windows computed, now building the model
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_16 (LSTM)              (None, 10)                520
#
#  dense_48 (Dense)            (None, 16)                176
#
#  dense_49 (Dense)            (None, 16)                272
#
#  dense_50 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 985
# Trainable params: 985
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 2ms/step
# Window 5, covariates ('pressure',): [22.18322893]
#
#
#                                       EXECUTING 10 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_17 (LSTM)              (None, 20)                1840
#
#  dense_51 (Dense)            (None, 16)                336
#
#  dense_52 (Dense)            (None, 16)                272
#
#  dense_53 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 2,465
# Trainable params: 2,465
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 3ms/step
# Window 10, covariates ('pressure',): [18.0426156]
#
#
#                                       EXECUTING 15 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_18 (LSTM)              (None, 30)                3960
#
#  dense_54 (Dense)            (None, 16)                496
#
#  dense_55 (Dense)            (None, 16)                272
#
#  dense_56 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 4,745
# Trainable params: 4,745
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 4ms/step
# Window 15, covariates ('pressure',): [16.0029693]
#
#
#                                       EXECUTING 25 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_19 (LSTM)              (None, 50)                10600
#
#  dense_57 (Dense)            (None, 16)                816
#
#  dense_58 (Dense)            (None, 16)                272
#
#  dense_59 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 11,705
# Trainable params: 11,705
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 6ms/step
# Window 25, covariates ('pressure',): [20.65869784]
# ****************************************************************************************************
#
#
# *************************************EXECUTING OVER: ('tvoc',)**************************************
#
#
#                                       EXECUTING 1 WINDOW SIZE                                        -
#
#
# Windows computed, now building the model
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_20 (LSTM)              (None, 2)                 40
#
#  dense_60 (Dense)            (None, 16)                48
#
#  dense_61 (Dense)            (None, 16)                272
#
#  dense_62 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 377
# Trainable params: 377
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 2ms/step
# Window 1, covariates ('tvoc',): [24.41273889]
#
#
#                                       EXECUTING 5 WINDOW SIZE                                        -
#
#
# Windows computed, now building the model
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_21 (LSTM)              (None, 10)                520
#
#  dense_63 (Dense)            (None, 16)                176
#
#  dense_64 (Dense)            (None, 16)                272
#
#  dense_65 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 985
# Trainable params: 985
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 3ms/step
# Window 5, covariates ('tvoc',): [21.20009954]
#
#
#                                       EXECUTING 10 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_22 (LSTM)              (None, 20)                1840
#
#  dense_66 (Dense)            (None, 16)                336
#
#  dense_67 (Dense)            (None, 16)                272
#
#  dense_68 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 2,465
# Trainable params: 2,465
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 3ms/step
# Window 10, covariates ('tvoc',): [16.43601617]
#
#
#                                       EXECUTING 15 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_23 (LSTM)              (None, 30)                3960
#
#  dense_69 (Dense)            (None, 16)                496
#
#  dense_70 (Dense)            (None, 16)                272
#
#  dense_71 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 4,745
# Trainable params: 4,745
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 4ms/step
# Window 15, covariates ('tvoc',): [16.31596897]
#
#
#                                       EXECUTING 25 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_24 (LSTM)              (None, 50)                10600
#
#  dense_72 (Dense)            (None, 16)                816
#
#  dense_73 (Dense)            (None, 16)                272
#
#  dense_74 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 11,705
# Trainable params: 11,705
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 5ms/step
# Window 25, covariates ('tvoc',): [16.66585294]
# ****************************************************************************************************
#
#
# *******************************EXECUTING OVER: ('state', 'humidity')********************************
#
#
#                                       EXECUTING 1 WINDOW SIZE                                        -
#
#
# Windows computed, now building the model
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_25 (LSTM)              (None, 2)                 48
#
#  dense_75 (Dense)            (None, 16)                48
#
#  dense_76 (Dense)            (None, 16)                272
#
#  dense_77 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 385
# Trainable params: 385
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 0s 2ms/step
# Window 1, covariates ('state', 'humidity'): [27.91912421]
#
#
#                                       EXECUTING 5 WINDOW SIZE                                        -
#
#
# Windows computed, now building the model
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_26 (LSTM)              (None, 10)                560
#
#  dense_78 (Dense)            (None, 16)                176
#
#  dense_79 (Dense)            (None, 16)                272
#
#  dense_80 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 1,025
# Trainable params: 1,025
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 0s 2ms/step
# Window 5, covariates ('state', 'humidity'): [21.93906002]
#
#
#                                       EXECUTING 10 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_27"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_27 (LSTM)              (None, 20)                1920
#
#  dense_81 (Dense)            (None, 16)                336
#
#  dense_82 (Dense)            (None, 16)                272
#
#  dense_83 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 2,545
# Trainable params: 2,545
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 0s 2ms/step
# Window 10, covariates ('state', 'humidity'): [17.06708468]
#
#
#                                       EXECUTING 15 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_28"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_28 (LSTM)              (None, 30)                4080
#
#  dense_84 (Dense)            (None, 16)                496
#
#  dense_85 (Dense)            (None, 16)                272
#
#  dense_86 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 4,865
# Trainable params: 4,865
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 3ms/step
# Window 15, covariates ('state', 'humidity'): [20.74260827]
#
#
#                                       EXECUTING 25 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_29"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_29 (LSTM)              (None, 50)                10800
#
#  dense_87 (Dense)            (None, 16)                816
#
#  dense_88 (Dense)            (None, 16)                272
#
#  dense_89 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 11,905
# Trainable params: 11,905
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 5ms/step
# Window 25, covariates ('state', 'humidity'): [19.38374796]
# ****************************************************************************************************
#
#
# *******************************EXECUTING OVER: ('state', 'pressure')********************************
#
#
#                                       EXECUTING 1 WINDOW SIZE                                        -
#
#
# Windows computed, now building the model
# Model: "sequential_30"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_30 (LSTM)              (None, 2)                 48
#
#  dense_90 (Dense)            (None, 16)                48
#
#  dense_91 (Dense)            (None, 16)                272
#
#  dense_92 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 385
# Trainable params: 385
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 0s 2ms/step
# Window 1, covariates ('state', 'pressure'): [25.56837969]
#
#
#                                       EXECUTING 5 WINDOW SIZE                                        -
#
#
# Windows computed, now building the model
# Model: "sequential_31"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_31 (LSTM)              (None, 10)                560
#
#  dense_93 (Dense)            (None, 16)                176
#
#  dense_94 (Dense)            (None, 16)                272
#
#  dense_95 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 1,025
# Trainable params: 1,025
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 0s 2ms/step
# Window 5, covariates ('state', 'pressure'): [18.59794476]
#
#
#                                       EXECUTING 10 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_32"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_32 (LSTM)              (None, 20)                1920
#
#  dense_96 (Dense)            (None, 16)                336
#
#  dense_97 (Dense)            (None, 16)                272
#
#  dense_98 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 2,545
# Trainable params: 2,545
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 0s 3ms/step
# Window 10, covariates ('state', 'pressure'): [18.21469149]
#
#
#                                       EXECUTING 15 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_33"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_33 (LSTM)              (None, 30)                4080
#
#  dense_99 (Dense)            (None, 16)                496
#
#  dense_100 (Dense)           (None, 16)                272
#
#  dense_101 (Dense)           (None, 1)                 17
#
# =================================================================
# Total params: 4,865
# Trainable params: 4,865
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 3ms/step
# Window 15, covariates ('state', 'pressure'): [18.95774023]
#
#
#                                       EXECUTING 25 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_34 (LSTM)              (None, 50)                10800
#
#  dense_102 (Dense)           (None, 16)                816
#
#  dense_103 (Dense)           (None, 16)                272
#
#  dense_104 (Dense)           (None, 1)                 17
#
# =================================================================
# Total params: 11,905
# Trainable params: 11,905
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 5ms/step
# Window 25, covariates ('state', 'pressure'): [19.33862667]
# ****************************************************************************************************
#
#
# *********************************EXECUTING OVER: ('state', 'tvoc')**********************************
#
#
#                                       EXECUTING 1 WINDOW SIZE                                        -
#
#
# Windows computed, now building the model
# Model: "sequential_35"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_35 (LSTM)              (None, 2)                 48
#
#  dense_105 (Dense)           (None, 16)                48
#
#  dense_106 (Dense)           (None, 16)                272
#
#  dense_107 (Dense)           (None, 1)                 17
#
# =================================================================
# Total params: 385
# Trainable params: 385
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 0s 1ms/step
# Window 1, covariates ('state', 'tvoc'): [28.61708385]
#
#
#                                       EXECUTING 5 WINDOW SIZE                                        -
#
#
# Windows computed, now building the model
# Model: "sequential_36"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_36 (LSTM)              (None, 10)                560
#
#  dense_108 (Dense)           (None, 16)                176
#
#  dense_109 (Dense)           (None, 16)                272
#
#  dense_110 (Dense)           (None, 1)                 17
#
# =================================================================
# Total params: 1,025
# Trainable params: 1,025
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 2ms/step
# Window 5, covariates ('state', 'tvoc'): [20.84758483]
#
#
#                                       EXECUTING 10 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_37"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_37 (LSTM)              (None, 20)                1920
#
#  dense_111 (Dense)           (None, 16)                336
#
#  dense_112 (Dense)           (None, 16)                272
#
#  dense_113 (Dense)           (None, 1)                 17
#
# =================================================================
# Total params: 2,545
# Trainable params: 2,545
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 0s 3ms/step
# Window 10, covariates ('state', 'tvoc'): [17.62070013]
#
#
#                                       EXECUTING 15 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_38"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_38 (LSTM)              (None, 30)                4080
#
#  dense_114 (Dense)           (None, 16)                496
#
#  dense_115 (Dense)           (None, 16)                272
#
#  dense_116 (Dense)           (None, 1)                 17
# ...
#  lstm_62 (LSTM)              (None, 20)                2000
#
#  dense_186 (Dense)           (None, 16)                336
#
#  dense_187 (Dense)           (None, 16)                272
#
#  dense_188 (Dense)           (None, 1)                 17
#
# =================================================================
# Total params: 2,625
# Trainable params: 2,625
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 3ms/step
# Window 10, covariates ('state', 'humidity', 'tvoc'): [18.38718835]
#
#
#                                       EXECUTING 15 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_63"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_63 (LSTM)              (None, 30)                4200
#
#  dense_189 (Dense)           (None, 16)                496
#
#  dense_190 (Dense)           (None, 16)                272
#
#  dense_191 (Dense)           (None, 1)                 17
#
# =================================================================
# Total params: 4,985
# Trainable params: 4,985
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 4ms/step
# Window 15, covariates ('state', 'humidity', 'tvoc'): [18.00098871]
#
#
#                                       EXECUTING 25 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_64"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_64 (LSTM)              (None, 50)                11000
#
#  dense_192 (Dense)           (None, 16)                816
#
#  dense_193 (Dense)           (None, 16)                272
#
#  dense_194 (Dense)           (None, 1)                 17
#
# =================================================================
# Total params: 12,105
# Trainable params: 12,105
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 2s 7ms/step
# Window 25, covariates ('state', 'humidity', 'tvoc'): [20.53811103]
# ****************************************************************************************************
#
#
# ***************************EXECUTING OVER: ('state', 'pressure', 'tvoc')****************************
#
#
#                                       EXECUTING 1 WINDOW SIZE                                        -
#
#
# Windows computed, now building the model
# Model: "sequential_65"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_65 (LSTM)              (None, 2)                 56
#
#  dense_195 (Dense)           (None, 16)                48
#
#  dense_196 (Dense)           (None, 16)                272
#
#  dense_197 (Dense)           (None, 1)                 17
#
# =================================================================
# Total params: 393
# Trainable params: 393
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 2ms/step
# Window 1, covariates ('state', 'pressure', 'tvoc'): [28.56518231]
#
#
#                                       EXECUTING 5 WINDOW SIZE                                        -
#
#
# Windows computed, now building the model
# Model: "sequential_66"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_66 (LSTM)              (None, 10)                600
#
#  dense_198 (Dense)           (None, 16)                176
#
#  dense_199 (Dense)           (None, 16)                272
#
#  dense_200 (Dense)           (None, 1)                 17
#
# =================================================================
# Total params: 1,065
# Trainable params: 1,065
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 3ms/step
# Window 5, covariates ('state', 'pressure', 'tvoc'): [25.55606059]
#
#
#                                       EXECUTING 10 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_67"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_67 (LSTM)              (None, 20)                2000
#
#  dense_201 (Dense)           (None, 16)                336
#
#  dense_202 (Dense)           (None, 16)                272
#
#  dense_203 (Dense)           (None, 1)                 17
#
# =================================================================
# Total params: 2,625
# Trainable params: 2,625
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 3ms/step
# Window 10, covariates ('state', 'pressure', 'tvoc'): [16.91696096]
#
#
#                                       EXECUTING 15 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_68"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_68 (LSTM)              (None, 30)                4200
#
#  dense_204 (Dense)           (None, 16)                496
#
#  dense_205 (Dense)           (None, 16)                272
#
#  dense_206 (Dense)           (None, 1)                 17
#
# =================================================================
# Total params: 4,985
# Trainable params: 4,985
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 4ms/step
# Window 15, covariates ('state', 'pressure', 'tvoc'): [19.68100796]
#
#
#                                       EXECUTING 25 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_69"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_69 (LSTM)              (None, 50)                11000
#
#  dense_207 (Dense)           (None, 16)                816
#
#  dense_208 (Dense)           (None, 16)                272
#
#  dense_209 (Dense)           (None, 1)                 17
#
# =================================================================
# Total params: 12,105
# Trainable params: 12,105
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 6ms/step
# Window 25, covariates ('state', 'pressure', 'tvoc'): [20.66857963]
# ****************************************************************************************************
#
#
# **************************EXECUTING OVER: ('humidity', 'pressure', 'tvoc')**************************
#
#
#                                       EXECUTING 1 WINDOW SIZE                                        -
#
#
# Windows computed, now building the model
# Model: "sequential_70"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_70 (LSTM)              (None, 2)                 56
#
#  dense_210 (Dense)           (None, 16)                48
#
#  dense_211 (Dense)           (None, 16)                272
#
#  dense_212 (Dense)           (None, 1)                 17
#
# =================================================================
# Total params: 393
# Trainable params: 393
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 2ms/step
# Window 1, covariates ('humidity', 'pressure', 'tvoc'): [54.01992053]
#
#
#                                       EXECUTING 5 WINDOW SIZE                                        -
#
#
# Windows computed, now building the model
# Model: "sequential_71"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_71 (LSTM)              (None, 10)                600
#
#  dense_213 (Dense)           (None, 16)                176
#
#  dense_214 (Dense)           (None, 16)                272
#
#  dense_215 (Dense)           (None, 1)                 17
#
# =================================================================
# Total params: 1,065
# Trainable params: 1,065
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 2ms/step
# Window 5, covariates ('humidity', 'pressure', 'tvoc'): [22.51567089]
#
#
#                                       EXECUTING 10 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_72"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_72 (LSTM)              (None, 20)                2000
#
#  dense_216 (Dense)           (None, 16)                336
#
#  dense_217 (Dense)           (None, 16)                272
#
#  dense_218 (Dense)           (None, 1)                 17
#
# =================================================================
# Total params: 2,625
# Trainable params: 2,625
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 3ms/step
# Window 10, covariates ('humidity', 'pressure', 'tvoc'): [21.36502322]
#
#
#                                       EXECUTING 15 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_73"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_73 (LSTM)              (None, 30)                4200
#
#  dense_219 (Dense)           (None, 16)                496
#
#  dense_220 (Dense)           (None, 16)                272
#
#  dense_221 (Dense)           (None, 1)                 17
#
# =================================================================
# Total params: 4,985
# Trainable params: 4,985
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 4ms/step
# Window 15, covariates ('humidity', 'pressure', 'tvoc'): [33.05570786]
#
#
#                                       EXECUTING 25 WINDOW SIZE                                       -
#
#
# Windows computed, now building the model
# Model: "sequential_74"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_74 (LSTM)              (None, 50)                11000
#
#  dense_222 (Dense)           (None, 16)                816
#
#  dense_223 (Dense)           (None, 16)                272
#
#  dense_224 (Dense)           (None, 1)                 17
#
# =================================================================
# Total params: 12,105
# Trainable params: 12,105
# Non-trainable params: 0
# _________________________________________________________________
# 38/38 [==============================] - 1s 6ms/step
# Window 25, covariates ('humidity', 'pressure', 'tvoc'): [20.99906637]
# ****************************************************************************************************

# %%
model.save("../output/radon.h5", save_format = "h5")

# %%
model.save("../output/radon.pb", save_format = "tf")

# %%
summer_min, summer_max

# %%
pd.DataFrame(
    {
        "predictions": prediction.flatten(),
        "real": real.flatten(),
    }
).to_csv("../data/prediction1s.csv", index = False)
