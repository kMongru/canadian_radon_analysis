# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/predictions.csv')
df.head()
# Out:
#    predictions   real
# 0     318.8814  344.0
# 1     379.7212  344.0
# 2     350.7884  319.0
# 3     302.3704  324.0
# 4     311.6256  293.0

# %%
df.plot(kind='scatter', x= 'predictions', y='real', )
plt.show()
