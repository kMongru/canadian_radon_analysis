# %% [markdown]
# <a href="https://colab.research.google.com/github/kMongru/canadian_radon_analysis/blob/main/originalData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

from sklearn.linear_model import LinearRegression

df = pd.read_csv('./Pearson.tsv',
                 delim_whitespace=True)
df.head() # prodce a header from the first data row


# LinearRegression will expect an array of shape (n, 1) 
# for the "Training data"
X = df['Father'].values[:,np.newaxis]
# target data is array of shape (n,) 
y = df['Son'].values


model2 = LinearRegression()
model2.fit(X, y)

plt.scatter(X, y,color='g')
plt.plot(X, model2.predict(X),color='k')

plt.show()

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

df = pd.read_csv('./radon-concentration.csv')

# Convert the AverageRadonConcentrationInBqPerM3 values to numeric
df['AverageRadonConcentrationInBqPerM3'] = pd.to_numeric(df['AverageRadonConcentrationInBqPerM3'], errors='coerce')

# Remove any row with the value <15
df = df[df['AverageRadonConcentrationInBqPerM3'] >= 15]

X = df['Postal Code'].values[:, np.newaxis]
y = df['AverageRadonConcentrationInBqPerM3'].values
df.dropna(inplace=True)

model = LinearRegression()
model.fit(X,y)

plt.scatter(X, y,color='g')
plt.plot(X, model2.predict(X),color='k')

plt.show()
# Out:
# 11229
# 11229
